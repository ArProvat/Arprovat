# %% [markdown]
# <a href="https://colab.research.google.com/github/Arprovat/Arprovat/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**
# It is python package which provide fast , flexible and one of the most powerfull data manupulation/analysis tool available in python and any language.
# It is built on the top of Numpy.
# ## **Data Type in Pandas**
# the two  primary type of pandas -
# - **Serise**: It is 1D data structure that can store same type of data,or we can say each coloum of *dataFrame* is a Serise.
# - **DataFrame**: It is 2D data structure that can store diffrent of type Like - int,flot,string in coloums,it is similar spreadsheet
#
# let's see how to create Datafream and appling methods...

# %%
import pandas as pd
import numpy as np

# %%
new_df = pd.DataFrame(np.random.randint(5, 20, size=(10,5)),columns=list('ABCDE')) #index=np.arange(10))

# %%
new_df
# Out:
#     A   B   C   D   E
# 0  15   7   6   6  13
# 1  16  16   5  14  14
# 2  11  11   7   9   8
# 3   8  16   6  18   9
# 4  19  16  10  16  16
# 5  19   7  14  10  15
# 6   6  11   5   8  10
# 7  18   8  19  12  10
# 8  13  14  11   8   7
# 9  14   7  15   6  15

# %%
dic_df = pd.DataFrame({
    "name":['provat','sahadat','nadim','masum'],
    'age':[22,23,23,23],
    "live":["BD",'saudi','Bd','Qatar']
} , index= np.arange(1,5))

# %%
dic_df
# Out:
#       name  age   live
# 1   provat   22     BD
# 2  sahadat   23  saudi
# 3    nadim   23     Bd
# 4    masum   23  Qatar

# %%
print(type(new_df))
print(type(dic_df['name']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
dic_df.head(2)
# Out:
#       name  age   live
# 1   provat   22     BD
# 2  sahadat   23  saudi

# %%
dic_df.tail(3)
# Out:
#       name  age   live
# 2  sahadat   23  saudi
# 3    nadim   23     Bd
# 4    masum   23  Qatar

# %%
new_df.loc[0]['A']#return specified row
# Out:
# 15

# %%
dic_df.loc[1]['age']
# Out:
# 22

# %%
dic_df.loc[1:4:2] # slice using loc
# Out:
#      name  age live
# 1  provat   22   BD
# 3   nadim   23   Bd

# %%
dic_df.loc['name':'live']
# Out:
# Empty DataFrame
# Columns: [name, age, live]
# Index: []

# %%
from google.colab import drive
drive.mount('/content/drive')
dic_df.to_excel('/content/drive/MyDrive/friends.xlsx')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pd.read_excel('/content/drive/MyDrive/friends.xlsx')
# Out:
#    Unnamed: 0     name  age   live
# 0           1   provat   22     BD
# 1           2  sahadat   23  saudi
# 2           3    nadim   24     Bd
# 3           4    masum   23  Qatar
